# %% [markdown]
# <a href="https://colab.research.google.com/github/BennamatAbdelbassit/Deep-Learning/blob/master/Deep_Learning_For_Traffic_Sign_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1- Project Overview

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=1nzr_ce5W4qwCG56mXw4-o6srne6qtuxz)

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=1mSnf3JlJmCe87jZEn8CWI3kMzp6rYbPH)

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons

# %% [markdown]
# #2- Import Libraries and Datasets

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=1ymVCBWDx_O0rPZIk8T1BYYhTXTppZBNq)

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %% [markdown]
# #3- Images Visualization

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 3

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')
plt.subplots_adjust(hspace = 0.4)

# %% [markdown]
# #4- Convert Images to grayscale and perform normalization

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_valid_gray = np.sum(X_validation/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_valid_gray_norm = (X_valid_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128

# %%
X_valid_gray_norm.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# #5 The theory and intuition behind CNNs

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=1DgYvXuua_VfbOOHX2DBmxWZHB5JdTy9m)

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=14KWAD9BFTcjmGQk0pQc0P_JQz7IQEnGq)

# %% [markdown]
# #6- Build our deep CNN model

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.4))

CNN.add(layers.Conv2D(16, (5, 5), activation='relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation='relu'))
CNN.add(layers.Dense(84, activation='relu'))
CNN.add(layers.Dense(43, activation='softmax'))
CNN.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_27 (Averag (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_28 (Averag (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 400)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 120)               48120
# _________________________________________________________________
# dense_43 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_44 (Dense)             (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #7- Compile and train our CNN model

# %%
CNN.compile(optimizer='adam', loss= 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(x= X_train_gray_norm, 
                  y= y_train, 
                  batch_size=500,
                  epochs = 50,
                  verbose = 1, 
                  validation_data = (X_valid_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 1s 9ms/step - loss: 3.3466 - accuracy: 0.1212 - val_loss: 3.2140 - val_accuracy: 0.1785
# Epoch 2/50
# 70/70 [==============================] - 1s 8ms/step - loss: 2.4164 - accuracy: 0.3454 - val_loss: 2.0480 - val_accuracy: 0.4515
# Epoch 3/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.4769 - accuracy: 0.5666 - val_loss: 1.2266 - val_accuracy: 0.6236
# Epoch 4/50
# 70/70 [==============================] - 1s 8ms/step - loss: 1.0059 - accuracy: 0.6983 - val_loss: 0.8839 - val_accuracy: 0.7356
# Epoch 5/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.8169 - accuracy: 0.7523 - val_loss: 0.7628 - val_accuracy: 0.7651
# Epoch 6/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6904 - accuracy: 0.7929 - val_loss: 0.6802 - val_accuracy: 0.7825
# Epoch 7/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.6218 - accuracy: 0.8111 - val_loss: 0.5975 - val_accuracy: 0.8150
# Epoch 8/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.5500 - accuracy: 0.8381 - val_loss: 0.5550 - val_accuracy: 0.8283
# Epoch 9/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4939 - accuracy: 0.8528 - val_loss: 0.5237 - val_accuracy: 0.8406
# Epoch 10/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4661 - accuracy: 0.8609 - val_loss: 0.4736 - val_accuracy: 0.8707
# Epoch 11/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.4156 - accuracy: 0.8758 - val_loss: 0.4454 - val_accuracy: 0.8771
# Epoch 12/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3821 - accuracy: 0.8878 - val_loss: 0.4617 - val_accuracy: 0.8673
# Epoch 13/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3562 - accuracy: 0.8947 - val_loss: 0.4251 - val_accuracy: 0.8812
# Epoch 14/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3347 - accuracy: 0.9035 - val_loss: 0.4354 - val_accuracy: 0.8723
# Epoch 15/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.3238 - accuracy: 0.9048 - val_loss: 0.4279 - val_accuracy: 0.8780
# Epoch 16/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2936 - accuracy: 0.9121 - val_loss: 0.4158 - val_accuracy: 0.8848
# Epoch 17/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2848 - accuracy: 0.9141 - val_loss: 0.3958 - val_accuracy: 0.8893
# Epoch 18/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2630 - accuracy: 0.9221 - val_loss: 0.3866 - val_accuracy: 0.8855
# Epoch 19/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2500 - accuracy: 0.9279 - val_loss: 0.4043 - val_accuracy: 0.8798
# Epoch 20/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2340 - accuracy: 0.9314 - val_loss: 0.4028 - val_accuracy: 0.8887
# Epoch 21/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2276 - accuracy: 0.9326 - val_loss: 0.3790 - val_accuracy: 0.8955
# Epoch 22/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2204 - accuracy: 0.9345 - val_loss: 0.3576 - val_accuracy: 0.8993
# Epoch 23/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2036 - accuracy: 0.9399 - val_loss: 0.3797 - val_accuracy: 0.8957
# Epoch 24/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.2010 - accuracy: 0.9411 - val_loss: 0.3829 - val_accuracy: 0.8986
# Epoch 25/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1916 - accuracy: 0.9438 - val_loss: 0.3443 - val_accuracy: 0.9098
# Epoch 26/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1867 - accuracy: 0.9440 - val_loss: 0.3601 - val_accuracy: 0.9041
# Epoch 27/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1819 - accuracy: 0.9460 - val_loss: 0.3607 - val_accuracy: 0.8966
# Epoch 28/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1650 - accuracy: 0.9509 - val_loss: 0.3764 - val_accuracy: 0.9045
# Epoch 29/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1637 - accuracy: 0.9513 - val_loss: 0.3656 - val_accuracy: 0.9041
# Epoch 30/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1552 - accuracy: 0.9546 - val_loss: 0.3596 - val_accuracy: 0.9066
# Epoch 31/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1525 - accuracy: 0.9559 - val_loss: 0.3814 - val_accuracy: 0.9100
# Epoch 32/50
# 70/70 [==============================] - 1s 7ms/step - loss: 0.1519 - accuracy: 0.9543 - val_loss: 0.3625 - val_accuracy: 0.9057
# Epoch 33/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1456 - accuracy: 0.9568 - val_loss: 0.3493 - val_accuracy: 0.9095
# Epoch 34/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1323 - accuracy: 0.9612 - val_loss: 0.3984 - val_accuracy: 0.9023
# Epoch 35/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1326 - accuracy: 0.9609 - val_loss: 0.3646 - val_accuracy: 0.9045
# Epoch 36/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1281 - accuracy: 0.9618 - val_loss: 0.3483 - val_accuracy: 0.9102
# Epoch 37/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1248 - accuracy: 0.9633 - val_loss: 0.3706 - val_accuracy: 0.9088
# Epoch 38/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1238 - accuracy: 0.9621 - val_loss: 0.3777 - val_accuracy: 0.9059
# Epoch 39/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1190 - accuracy: 0.9644 - val_loss: 0.3730 - val_accuracy: 0.9048
# Epoch 40/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1166 - accuracy: 0.9650 - val_loss: 0.3832 - val_accuracy: 0.9118
# Epoch 41/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1104 - accuracy: 0.9661 - val_loss: 0.4020 - val_accuracy: 0.9039
# Epoch 42/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1073 - accuracy: 0.9662 - val_loss: 0.4018 - val_accuracy: 0.9098
# Epoch 43/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1070 - accuracy: 0.9674 - val_loss: 0.3553 - val_accuracy: 0.9177
# Epoch 44/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1011 - accuracy: 0.9695 - val_loss: 0.3110 - val_accuracy: 0.9213
# Epoch 45/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.1034 - accuracy: 0.9687 - val_loss: 0.3638 - val_accuracy: 0.9143
# Epoch 46/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0990 - accuracy: 0.9694 - val_loss: 0.3952 - val_accuracy: 0.9093
# Epoch 47/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0959 - accuracy: 0.9707 - val_loss: 0.3535 - val_accuracy: 0.9111
# Epoch 48/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0929 - accuracy: 0.9719 - val_loss: 0.3772 - val_accuracy: 0.9129
# Epoch 49/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0883 - accuracy: 0.9729 - val_loss: 0.3746 - val_accuracy: 0.9098
# Epoch 50/50
# 70/70 [==============================] - 1s 8ms/step - loss: 0.0918 - accuracy: 0.9717 - val_loss: 0.3533 - val_accuracy: 0.9111

# %% [markdown]
# #8- CNN model performance

# %% [markdown]
# ![alt text](http://drive.google.com/uc?export=view&id=1nZMfCow6pAG9WwQUdyrTzSOxNKp1gaoF)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.5174 - accuracy: 0.9049
# Test Accuracy: 0.9049089550971985

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label = 'Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
